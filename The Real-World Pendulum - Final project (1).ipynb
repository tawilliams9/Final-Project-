# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
g = 9.81   # gravitational acceleration (m/s^2)
L = 1.0    # length of pendulum (m)

# %%
# --- 2. EQUATION OF MOTION ---
# d^2θ/dt^2 = -(g/L) sin(θ)

def pendulum_ode(t, y):
    theta = y[0]   # angular position
    omega = y[1]   # angular velocity
    
    dtheta_dt = omega
    domega_dt = -(g / L) * np.sin(theta)
    
    return [dtheta_dt, domega_dt]

# %%
# --- 3. TIME GRID ---
import numpy as np  

t_start = 0
t_end = 20
t_points = 3000

t_eval = np.linspace(t_start, t_end, t_points)

# %%
angles_deg = np.linspace(1, 90, 30)
angles_rad = np.radians(angles_deg)

periods = []

for angle in angles_rad:
    T = compute_period(angle)
    periods.append(T)

# %%
L = 1.0   
g = 9.81
angles_deg = [10, 20, 30]  
T_theory = 2 * np.pi * np.sqrt(L / g)
T_theory_list = [T_theory] * len(angles_deg)

# %%
import matplotlib.pyplot as plt
import numpy as np

angles_deg = np.array(angles_deg)

plt.figure()
plt.plot(angles_deg, periods, label="Numerical Period")
plt.plot(angles_deg, T_theory_list, "--", label="Theory")

plt.xlabel("Angle (deg)")
plt.ylabel("Period (s)")
plt.title("Pendulum Period vs Angle")
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np

def pendulum(t, y):
    theta, omega = y
    g = 9.81
    L = 1.0  

    dtheta_dt = omega
    domega_dt = -(g / L) * np.sin(theta)

    return [dtheta_dt, domega_dt]
from scipy.integrate import solve_ivp
import numpy as np
import matplotlib.pyplot as plt

theta0 = np.radians(45)

t_span = (0, 10)
t_eval = np.linspace(0, 10, 1000)

sol = solve_ivp(pendulum, t_span, [theta0, 0], t_eval=t_eval)

plt.figure()
plt.plot(sol.t, sol.y[0])

plt.xlabel("Time (s)")
plt.ylabel("Angle (rad)")
plt.title("Pendulum Motion (45 degrees)")
plt.grid()
plt.show()
